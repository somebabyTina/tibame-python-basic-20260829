# %% [markdown]
# <a href="https://colab.research.google.com/github/somebabyTina/tibame-python-basic-20260829/blob/main/Lesson2_Enviornment.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#bmi:weight(kg)/height(m) ^ 2
weight = float(input("輸入體重:"))
height = float(input("輸入身高:"))

print('你的身高是: ',height,'公分')
print('你的體重是: ',weight,'公斤')
print(weight/(height/100)**2)

# %%
# 1. 預設的 float (浮點數) 型態：會出現微小誤差
print(0.1 + 0.2)
# 執行結果會是：0.30000000000000004 (而不是完美的 0.3)

# 2. Decimal 型態：強制字串轉換為精確的十進位運算
from decimal import Decimal
print(Decimal('0.1') + Decimal('0.2'))
# 執行結果會是：0.3

# %%
#石頭>剪刀>布>石頭>剪刀..
import random

list = ["剪刀","石頭","布"]
dist = (0:"剪刀",1:"石頭",2:布")
person1=input("請輸入 0:剪刀、1:石頭、2:布:")
com = random.randint(0,2)
print(person1)
print(com)
